# %% [markdown]
# # Making a agent and the prompting technique

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="openrouter:gemini-3.5-flash-lite")

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

print(response['messages'][-1].content)
# Out:
# The Moon doesn't have a capital because it doesn't have any countries, governments, or permanent human settlements.
#
# However, if you're looking for the "capital" in terms of exploration or history, **Tranquility Base** (the site where Apollo 11 landed in 1969) is often considered the most historically significant location on the lunar surface.
#
# Under international law (specifically the Outer Space Treaty of 1967), no nation can claim sovereignty over any part of the Moon, so a capital city is unlikely to be established there anytime soon!

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
                  AIMessage(content="The capital of the Moon is Crater of the Moon."),
                  HumanMessage(content="What's the capital of the Moon?")]}
)

print(response['messages'][-1].content)
# Out:
# The Moon does not have a capital because it is a natural satellite of Earth and has no human governments, cities, or nations.
#
# While humans have sent probes, landers, and astronauts to various sites on the Moon (such as Tranquility Base, where Apollo 11 landed), none of these locations serve as a capital.

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# **Luna City**—often referred to simply as "The Crater Capital" or "Selenopolis"—is the fictional (and occasionally speculative) capital city of the Moon. While humanity has not yet built a permanent metropolis on the lunar surface, Luna City is a staple of science fiction, futurism, and space colonization proposals.
#
# To give you the full picture, we have to look at Luna City through three lenses: **Speculative Engineering** (how we would actually build it), **Science Fiction** (how it’s portrayed in media), and **Daily Life** (what it would feel like to live there).
#
# ---
#
# ### 1. Where and How: The Engineering of Luna City
# In both real-world proposals (like NASA’s Artemis base concepts and ESA’s "Moon Village") and sci-fi lore, building a city on the Moon is an extreme engineering challenge.
#
# *   **Location, Location, Location:** Luna City is usually imagined near the **Moon’s South Pole** (near Shackleton Crater). Why? Because of the "Peaks of Eternal Light"—ridges that receive near-constant sunlight for solar power, combined with permanently shadowed craters nearby that contain billions of tons of water ice for drinking, oxygen, and rocket fuel.
# *   **The Regolith Shield:** To protect citizens from cosmic radiation, solar flares, and micrometeorites, Luna City cannot be made of glass domes sitting openly on the surface (a trope of retro-sci-fi). Instead, Luna City is either **subterranean** (dug into the volcanic lava tubes beneath the lunar crust) or **surface-based modules buried under 3 to 10 feet of *regolith*** (Moon dust/dirt).
# *   **Architecture:** Think pressurized geodesic domes, inflatable habitats connected by reinforced tunnels, and repurposed empty rocket fuel tanks.
#
# ---
#
# ### 2. Life in Luna City: Culture and Environment
# Living in the capital of the Moon would be vastly different from living on Earth, shaped by two major factors: **1/6th gravity** and **isolation**.
#
# *   **The G-Movement:** Moving around Luna City is athletic and bouncy. People wear weighted packs to keep their bones and muscles from degenerating in the low gravity. Sports are entirely reinvented: "Lunar basketball" involves hoops mounted 30 feet in the air, and high-jumping is effortless.
# *   **The Economy:** Luna City isn't just a science base; it’s a booming industrial hub. Its economy relies on:
#     *   **He-3 Mining:** Harvesting Helium-3 from lunar dust for nuclear fusion reactors back on Earth.
#     *   **Space Tourism:** Luxury hotels catering to ultra-wealthy Earthlings wanting to see the "Earth-rise."
#     *   **Deep Space Launchpad:** Because the Moon has a fraction of Earth's gravity and no atmosphere, launching rockets from Luna City to Mars and beyond requires a fraction of the fuel.
# *   **The View:** The sky is pitch black, dotted with unblinking stars, and the Sun is blindingly bright. But the crown jewel of the Luna City skyline is **Earth**. Hanging permanently in the sky (depending on which side of the Moon you're on), Earth looks like a glowing blue-and-white marble, slowly rotating through its phases over the course of a 28-day lunar month.
#
# ---
#
# ### 3. Luna City in Science Fiction
# Luna City (or cities very much like it) has a rich history in literature and pop culture:
#
# *   **Robert A. Heinlein’s *The Moon Is a Harsh Mistress*:** Features "Luna City" (often called "Port Luna" or "Nutetown"), a penal colony that eventually stages a revolution against Earth using mass drivers to hurl rocks at the home planet.
# *   **Andy Weir’s *Artemis*:** Set in the first and only city on the Moon, Artemis. While technically a city rather than the capital, it gives a gritty, realistic depiction of lunar economics, smuggling, and everyday life in a low-gravity frontier town.
# *   **Philip K. Dick and Arthur C. Clarke:** Both authors frequently used lunar settlements as bureaucratic hubs for interplanetary governments or quiet retirement spots for weary space travelers.
#
# ---
#
# ### Summary: The Vibe of Luna City
# Imagine a mix between an Antarctic research station, a high-tech mining town in the Yukon, and an orbital space station. It smells like spent gunpowder (due to the abrasive, clingy moondust tracked inside). Its citizens are a hardy breed of scientists, miners, engineers, and spacers known as **"Lunarians"** or **"Selenites."**
#
# While it sounds harsh, to the people of Luna City, looking up at the pale blue dot of Earth—where people are weighed down by gravity and bogged down by atmospheric politics—they wouldn't trade their crater capital for the world.

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="openrouter:gemini-3.5-flash-lite",
    system_prompt=system_prompt
)

question = HumanMessage(content="What's the capital of the moon?")

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Officially, it is designated **Selene Prime**, but among the dust-miners, corporate brokers, and low-gee acrobats who live there, it is simply called **The Basin**.
#
# Nestled entirely within the shadows of the ancient, ringed crater Shackleton at the lunar South Pole, The Basin is a city that defies the sun. While the peaks surrounding the crater are bathed in a permanent, blinding glare of solar-farm gold, the city itself rests in perpetual, freezing darkness.
#
# Here is what it looks, feels, and sounds like to step out of the tram and into humanity’s most ambitious off-world metropolis:
#
# ### Architecture: The Hanging Spires
# You do not build *up* in a vacuum with one-sixth gravity; you build *inward*. The interior walls of the Shackleton crater have been hollowed, reinforced, and honeycombed with millions of hexagonal habitation pods made from sintered lunar glass and carbon nanotubes.
# From the center of the crater floor rises the **Spindle**—a towering, ten-kilometer-high carbon-fiber elevator anchor that stretches toward the zenith, tethered to a counter-weight mass far above. Glowing elevator cars crawl up and down its length like luminous insects, moving freight and elites between the surface and the orbital docks.
#
# ### The Atmosphere (Literally)
# The air in The Basin smells perpetually of ozone, recycled cardamom, and the sharp, metallic tang of pulverized regolith (which clings to everything despite electrostatic scrubbers). Because atmospheric pressure is kept at a comfortable 70% of Earth-normal, the air feels thick, humid, and heavy in your lungs—a deliberate luxury imported from the massive algae vats in the equatorial lava tubes.
#
# ### Life in Low-G
# Movement in The Basin is an art form. New arrivals (“Droppers”) stumble and bound clumsily, while locals glide with long, lazy strides, often utilizing waist-tethers or magnetic-soled boots to snap themselves to walkways.
# The main thoroughfare is **The Ring**, a curving concourse that circles the crater floor. It is lined with 3D-printed cafes serving lab-grown wagyu and hydroponic greens, zero-gravity night-clubs where patrons dance in slow-motion suspended by elastic harnesses, and bustling bazaars where titanium tools trade alongside rare Martian data-shards.
#
# ### The Crown Jewel: The Ice-Tap
# The capital exists here for one reason: water. Deep beneath the city floor lies the Shackleton Glacier, an ancient reserve of pristine comet-ice trapped in the permanent cryogenic dark. **The Ice-Tap**, a colossal industrial cathedral, drills miles down into the permafrost, melting and purifying water not just for the city’s million residents, but to fuel the fusion torch-ships heading out to the Jovian moons.
#
# ### Politics and Power
# The Basin is ruled by the **Lunar Directorate**, a volatile triumvirate representing the three mega-corporations that funded its construction: United Helium, Ceres-Terraforming, and the independent miners’ union known as the Grey Collective. It is a city of sharp contrasts—where hyper-wealthy executives sipping synthetic champagne in glass penthouses look down (or rather, *up*) at the towering crater rims, while miles below, blue-collar stakers risk the solar flares to mine the rare earths that keep Earth's glowing cities alive.
#
# To stand on the observation deck of The Basin and look up is to experience vertigo: the crater rim blocks out the stars, forming a jagged, pitch-black circle of the lunar night, directly through which hangs the brilliant, impossibly blue sapphire of Earth, rising and setting every twenty-eight days.

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="openrouter:gemini-3.5-flash-lite",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Seleneopolis

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="openrouter:gemini-3.5-flash-lite",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Selenopolis Prime
#
# Location: The Shackleton Crater, situated at the Moon’s south pole, taking advantage of the eternal peaks of light and the permanently shadowed ice-reservoirs below.
#
# Vibe: Brutalist, luminescent, industrious
#
# Economy: Lunar helium-3 mining, deep-space launch logistics, and zero-gravity bio-pharmaceutical manufacturing.

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='openrouter:gemini-3.5-flash-lite',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Selenopolis-Prime', location='The permanently shadowed craters of the Shackleton Crater rim', vibe='A bustling, vertical subterranean metropolis bathed in neon blue-white luminescence, where corporate suits, asteroid miners, and bio-engineered citizens navigate low-g mag-trains and bioluminescent parks.', economy='He3-mining, quantum computing credits, and lunar tourism')

# %%
response["structured_response"].name
# Out:
# 'Selenopolis-Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Selenopolis-Prime is a city located at The permanently shadowed craters of the Shackleton Crater rim
