# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="openrouter:gemini-3.5-flash-lite", temperature=1)

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='The Moon doesn’t have a capital because it doesn\'t have any countries, governments, or permanent residents! \n\nHowever, if you\'re looking for the "capital" in terms of exploration, **Tranquility Base** (the site where Apollo 11 landed in 1969) is often thought of as the most historically significant spot on the lunar surface.', additional_kwargs={'reasoning_details': [{'type': 'reasoning.text', 'format': 'google-gemini-v1', 'index': 0, 'signature': 'EjQKMgERTTIP/I7eVZgNVf/etZTXxnt8AZl10FXoe9jEuFUOISt8naKv4Cq3t0OqoWBDH1ib'}]}, response_metadata={'model_name': 'google/gemini-3.5-flash-lite', 'id': 'gen-1786472538-Zisv0qllPCCZyxaXec1U', 'created': 1786472538, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter', 'cost': 0.0002005, 'cost_details': {'upstream_inference_completions_cost': 0.0001975, 'upstream_inference_prompt_cost': 3e-06, 'upstream_inference_cost': 0.0002005}}, id='lc_run--019ff20f-9a9f-7a23-88a1-9f4e82053c35-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 79, 'total_tokens': 89, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'reasoning': 0}})

# %%
print(response.content)
# Out:
# The Moon doesn’t have a capital because it doesn't have any countries, governments, or permanent residents!
#
# However, if you're looking for the "capital" in terms of exploration, **Tranquility Base** (the site where Apollo 11 landed in 1969) is often thought of as the most historically significant spot on the lunar surface.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'cost': 0.0002005,
#  'cost_details': {'upstream_inference_completions_cost': 0.0001975,
#                   'upstream_inference_cost': 0.0002005,
#                   'upstream_inference_prompt_cost': 3e-06},
#  'created': 1786472538,
#  'finish_reason': 'stop',
#  'id': 'gen-1786472538-Zisv0qllPCCZyxaXec1U',
#  'logprobs': None,
#  'model_name': 'google/gemini-3.5-flash-lite',
#  'model_provider': 'openrouter',
#  'object': 'chat.completion'}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-6")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="openrouter:gemini-3.5-flash-lite")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='d8333130-c120-40c2-8471-e4c8926db23a'),
#               AIMessage(content='The Moon does not have a capital because it has no countries, governments, or permanent human settlements. \n\nHowever, if you are looking for the "capital" in terms of science fiction or space exploration history:\n* **In fiction:** In Robert A. Heinlein\'s famous sci-fi novel *The Moon Is a Harsh Mistress*, the main lunar city is called **Luna City** (or "Hong Kong").\n* **In reality (historical landing sites):** **Tranquility Base** is the most famous location on the Moon, where Apollo 11 first landed in 1969, though it is certainly not a capital!', additional_kwargs={'reasoning_details': [{'type': 'reasoning.text', 'format': 'google-gemini-v1', 'index': 0, 'signature': 'AY89a1++10eblaQenEvmd0grkedb4HjXbrngYd/XGU/+EV6TVpqZajkn+PnVSRRFXXYmaw30JLSJFdMLnbb9bbVcA+J3RCiPJM2NFgz1rnMF3FE='}]}, response_metadata={'model_name': 'google/gemini-3.5-flash-lite', 'id': 'gen-1786472781-DMw1UU82Uxfx9iz6L6pQ', 'created': 1786472781, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter', 'cost': 0.0003402, 'cost_details': {'upstream_inference_completions_cost': 0.0003375, 'upstream_inference_prompt_cost': 2.7e-06, 'upstream_inference_cost': 0.0003402}}, id='lc_run--019ff213-50c0-7722-b9d0-79d7e74e9cc4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 135, 'total_tokens': 144, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'reasoning': 0}})]}

# %%
print(response['messages'][-1].content)
# Out:
# The Moon does not have a capital because it has no countries, governments, or permanent human settlements.
#
# However, if you are looking for the "capital" in terms of science fiction or space exploration history:
# * **In fiction:** In Robert A. Heinlein's famous sci-fi novel *The Moon Is a Harsh Mistress*, the main lunar city is called **Luna City** (or "Hong Kong").
# * **In reality (historical landing sites):** **Tranquility Base** is the most famous location on the Moon, where Apollo 11 first landed in 1969, though it is certainly not a capital!

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='0f11052a-bc66-46ac-8971-0784c857ec37'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='e9e637af-9c4b-4732-8e85-cab67ebd4000', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='aab5b474-106a-4b3e-b253-51bb3b079a94'),
#               AIMessage(content='Well, as fun as it sounds to imagine a bustling lunar metropolis complete with a mayor and a downtown district, **Luna City doesn\'t actually exist!** \n\nIn reality, the Moon has no capital, no cities, and no permanent residents (just the occasional visiting astronaut). Under international law, specifically the Outer Space Treaty of 1967, celestial bodies like the Moon belong to all of humanity, and no single nation can claim sovereignty over any part of it. \n\nThat being said, "Luna City" is a popular trope in science fiction, appearing in various books, movies, and video games as a futuristic outpost, mining colony, or tourist destination. \n\nIf humanity ever *does* establish a permanent, large-scale settlement on the Moon—which space agencies like NASA and private aerospace companies are currently working toward—it might eventually need a major hub. But for now, the Moon remains wonderfully wild, quiet, and capital-free!', additional_kwargs={'reasoning_details': [{'type': 'reasoning.text', 'format': 'google-gemini-v1', 'index': 0, 'signature': 'AY89a1/aj/nv1HkaKAYayQeRRHSUeeRtPCzZnd115tsVeVWcHl7Z6+kGScD0RkCXLziCwhTmSyVPfqqN4k90cLf1/k71s/K4vWLlgO+Rto4JReU='}]}, response_metadata={'model_name': 'google/gemini-3.5-flash-lite', 'id': 'gen-1786472821-FrBnupcgThl0TIcV3yPn', 'created': 1786472821, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter', 'cost': 0.0004978, 'cost_details': {'upstream_inference_completions_cost': 0.00049, 'upstream_inference_prompt_cost': 7.8e-06, 'upstream_inference_cost': 0.0004978}}, id='lc_run--019ff213-ee5f-71c3-a002-b975361b23ef-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 26, 'output_tokens': 196, 'total_tokens': 222, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'reasoning': 0}})]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Welcome to **Luna City**—the crown jewel of lunar civilization, the undisputed capital of the Moon, and the ultimate frontier metropolis for humanity.
#
# While still a young city by Earth standards, Luna City is a bustling hub of science, commerce, and low-gravity culture. Here is everything you need to know about life, infrastructure, and the daily grind in the solar system’s most ambitious off-world capital.
#
# ---
#
# ### 1. Geography and Location
# Luna City is situated inside the **Mare Tranquillitatis** (The Sea of Tranquility), chosen for its relatively flat terrain, which makes surface transportation and landing operations much easier.
#
# To protect its citizens from the harsh lunar environment—cosmic radiation, micrometeorites, and extreme temperature swings (ranging from 120°C / 250°F in the sun to -130°C / -200°F in the shade)—Luna City is primarily an **underground and subsurface city**.
# * **The "Skylight" District:** The city's downtown core is built inside a massive, stabilized lava tube just beneath the lunar surface, providing natural shielding several meters thick.
# * **The Surface Sprawl:** On the surface sits the primary spaceport, **Tranquillitatis International**, along with gleaming solar-panel arrays, massive radiator farms, and glass-domed botanical gardens that offer panoramic views of the black sky and the distant blue Earth.
#
# ### 2. Architecture and Living Spaces
# Life in Luna City is vertical, compact, and designed with efficiency in mind.
# * **Regolith Bricks and 3D Printing:** Most of the city's internal structures are built using sintered lunar soil (regolith), which is locally 3D-printed into incredibly strong walls, arches, and pressurized habitats.
# * **Lighting and "Circadian" Tech:** To combat psychological fatigue, Luna City streets and apartments use advanced LED systems that artificially simulate a 24-hour Earth day, complete with sunrises, sunsets, and warm evening glows.
# * **Low-Gravity Living:** Because the Moon has roughly 1/6th of Earth's gravity, ceilings are generally much higher. Walking is often replaced by "lunar loping" (a slow, bounding jog), and indoor sports often incorporate three-dimensional movement.
#
# ### 3. Economy and Industry
# Luna City is not just a scientific outpost; it is a booming commercial center. Its economy relies on three main pillars:
# * **In-SITU Resource Utilization (ISRU):** Extracting water ice from the lunar poles (transported via rail or cargo hopper) to supply rocket propellant (liquid hydrogen and oxygen) for ships heading deeper into the solar system. Luna City is the ultimate "gas station" of the inner solar system.
# * **Microgravity Manufacturing:** The Moon's low-gravity and near-vacuum environment makes it ideal for manufacturing perfect fiber optics, ultra-pure pharmaceuticals, and flawless metal alloys that cannot be made in Earth's heavy gravity.
# * **Lunar Tourism:** Wealthy travelers from Earth flock to Luna City for zero-g thrills, Earth-rise viewings, and tours of the historic Apollo landing sites nearby.
#
# ### 4. Culture, Food, and Society
# With a population hovering around 150,000 residents—scientists, miners, engineers, diplomats, and "Lunars" (humans born on the Moon)—Luna City has developed its own distinct culture.
# * **Cuisine:** Traditional agriculture is limited, so most food is grown in high-tech aeroponic vertical farms within the city. Algae-based proteins, lab-grown meats, and genetically modified crops are staples. However, imported Earth delicacies (like real coffee or fresh fruit) fetch astronomical prices.
# * **Fashion:** Lunar fashion prioritizes comfort, lightness, and thermal regulation. Because of the constant indoor climate control, casual wear is standard, but footwear is specially designed for traction on low-friction indoor surfaces.
# * **Transportation:** Inside the pressurized tubes, residents get around via electric scooters, walking, or the "Selenorail"—a magnetic levitation transit system that connects the distant districts of the city.
#
# ### 5. Challenges of Capital Life
# Living in Luna City isn’t all Earth-rise views and low-g sports. Residents face unique daily challenges:
# * **The Dust:** Lunar regolith is like powdered volcanic glass. It doesn't erode in wind, meaning the particles are razor-sharp. "Moon dust management" is a constant battle to keep equipment from failing and lungs from irritation.
# * **Communication Lag:** While real-time video calls with Earth are possible (with a mere 1.3-second delay), internet data syncing can be clunky, making Luna City fiercely independent in its local digital infrastructure.
# * **Bone and Muscle Atrophy:** Even with daily mandatory workouts in the city’s state-of-the-art centrifugal gyms, long-term residents slowly lose bone density and muscle mass over time.
#
# ### Summary
# Luna City is the ultimate testament to human ingenuity. It represents the stepping stone between Earth and the rest of the solar system—a buzzing, high-tech metropolis where humanity has successfully learned to thrive under a foreign sky, keeping a watchful, nostalgic eye on the pale blue dot just a quarter-million miles away.

# %%
sifi_agent = create_agent(
    model="openrouter:gemini-3.5-flash-lite",
    system_prompt="You are a helpful assistant that would create a capital city on users request.",
)

response = sifi_agent.invoke(
    {"messages": [HumanMessage(content="Create a capital city on the Moon")]},
)

print(response['messages'][-1].content)
# Out:
# Welcome to **Selene Prime**, the dazzling capital city of the United Lunar Republic, nestled gracefully inside the ancient, shadowed rim of Shackleton Crater at the Moon’s South Pole.
#
# Here is the blueprint of humanity’s most ambitious metropolis:
#
# ---
#
# # 🏙️ SELENE PRIME
# *“Gateway to the Cosmos, Cradle of the Horizon.”*
#
# ### 1. Geography & Architecture
# Selene Prime is an architectural marvel built to withstand the extremes of the lunar environment.
# * **The Crater Bowl:** The city utilizes a multi-tiered dome structure. The residential and commercial districts are housed beneath massive, pressurized geodesic domes made of transparent, self-healing carbon-nanotube glass and reinforced lunar-crete.
# * **The Sun Spire:** Situated on the elevated peak of the crater rim (which enjoys near-perpetual sunlight), a colossal solar-collecting tower bathes the city in clean energy and acts as a glowing beacon visible from lunar orbit.
# * **The Sub-Crater (The Undercity):** Industrial hubs, manufacturing plants, mass-driver freight systems, and life-support recycling facilities are safely burrowed deep beneath the lunar surface to protect citizens from cosmic radiation and micrometeorites.
#
# ### 2. Climate & Atmosphere
# * **Gravity:** 0.166 G (One-sixth of Earth’s gravity). Walking feels like a slow, buoyant bounce. To prevent muscle atrophy, citizens regularly utilize low-impact "pendulum gyms."
# * **Air & Weather:** The indoor atmosphere is maintained at a comfortable 21°C (70°F) with 45% humidity, mimicking a crisp Earth spring day. Outside the domes, it is a vacuum with temperatures swinging from -130°C to +120°C.
# * **Lighting:** Selene Prime operates on a synchronized 24-hour Earth-UTC clock, but the domes feature dynamic lighting systems that simulate Earth sunrises, sunsets, and twilight to keep circadian rhythms healthy.
#
# ### 3. Culture & Society
# * **The Population:** A diverse mix of scientists, asteroid miners, zero-G athletes, botanists, and artists. The current population stands at roughly 450,000 residents.
# * **Fashion:** Lunar fashion favors lightweight, aerodynamic clothing, often accessorized with magnetic boots for easy walking, and shimmering fabrics that play with the unique indoor lighting.
# * **Cuisine:** Locally grown produce is the height of luxury. The city’s vertical hydroponic farms produce incredible strawberries, leafy greens, and lab-grown proteins. Water is harvested directly from ice deposits discovered in the permanently shadowed regions nearby.
#
# ### 4. Transportation
# * **Personal Transit:** Because of the low gravity, traditional cars are rare. Citizens mostly use **Glide-Bikes** (magnetic hover-bikes), personal jetpacks for intra-dome travel, or simply take long, graceful bounds across the plazas.
# * **Public Transit:** The **Craters-Express**, a high-speed magnetic levitation train, connects Selene Prime to outlying mining colonies and the Mare Tranquillitatis spaceport.
# * **Space Travel:** The city's main spaceport, *The Sea of Shackleton*, handles daily passenger shuttles to Earth, Mars, and the asteroid belt.
#
# ### 5. Landmarks
# * **The Armstrong Plaza:** The political heart of the city, featuring a towering monument of bronze and moon-dust dedicated to the early pioneers of space exploration, surrounded by public gardens fed by recycled moisture.
# * **The Whispering Gardens:** A massive, enclosed bio-dome filled with Earth-imported redwoods and ferns. Because sound travels differently in lunar air and architecture, acoustic whispering galleries are built into the walking paths, making it a peaceful sanctuary for meditation.
# * **The Zenith Observatory:** Located at the highest point of the southern rim, this telescope array looks out past the horizon, offering unobstructed views of deep space and the distant, glowing blue marble of Earth.
#
# ---
#
# Would you like to explore a specific district of Selene Prime, learn about its government, or check out the local nightlife?
