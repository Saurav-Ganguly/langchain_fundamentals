# %% [markdown]
# ## Tool definition

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool

@tool
def square_root(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root")
def tool1(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root", description="Calculate the square root of a number")
def tool1(x: float) -> float:
    return x ** 0.5

# %%
tool1.invoke({"x": 467})
# Out:
# 21.61018278497431

# %% [markdown]
# ## Adding to agents

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="openrouter:gemini-3.5-flash-lite",
    tools=[tool1],
    system_prompt="You are an arithmetic wizard. Use your tools to calculate the square root and square of any number."
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="What is the square root of 467?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The square root of 467 is approximately 21.61.

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='What is the square root of 467?', additional_kwargs={}, response_metadata={}, id='93a83d92-7e49-4820-a606-908a9b1c719c'),
#  AIMessage(content='', additional_kwargs={'reasoning_details': [{'data': 'El4KXAERTTIPbtgtUDt1WnP8pA3vhUwE2vW8NPU1aGVx/4QZDPtIkApXEgiY9D2aBFM93g1KtPET7VUs3tCUAr/Xnwwzp5f8qhp48KgLfzOOcZMBYejWgp9D2UQQ0SoW', 'type': 'reasoning.encrypted', 'format': 'google-gemini-v1', 'id': 'call_232205', 'index': 0}]}, response_metadata={'model_name': 'google/gemini-3.5-flash-lite', 'id': 'gen-1786636968-20SSEOuwh0DNdNfByZdy', 'created': 1786636968, 'object': 'chat.completion', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'openrouter', 'cost': 6.31e-05, 'cost_details': {'upstream_inference_completions_cost': 4e-05, 'upstream_inference_prompt_cost': 2.31e-05, 'upstream_inference_cost': 6.31e-05}}, id='lc_run--019ffbdc-9c9e-7430-8913-a8e043f9f21d-0', tool_calls=[{'name': 'square_root', 'args': {'x': 467}, 'id': 'call_232205', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 77, 'output_tokens': 16, 'total_tokens': 93, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'reasoning': 0}}),
#  ToolMessage(content='21.61018278497431', name='square_root', id='2538d262-9f05-44b9-bc40-1a92b86ce4c4', tool_call_id='call_232205'),
#  AIMessage(content='The square root of 467 is approximately 21.61.', additional_kwargs={'reasoning_details': [{'type': 'reasoning.text', 'format': 'google-gemini-v1', 'index': 0, 'signature': 'El4KXAERTTIPHVJ8yHY6mn/uBsPqGFAnhCmjsIKEo7dy9ZxwWCVKQgiFvkFjB923XBUscQ2+vBqMaD0W4y/XxqRhpj1Ld5rHlsSIKifhwPUnmp5lxzJKxV7uAbGhiY9o'}]}, response_metadata={'model_name': 'google/gemini-3.5-flash-lite', 'id': 'gen-1786636968-b7fzTOvGTJfQe9tjDRl8', 'created': 1786636968, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter', 'cost': 7.94e-05, 'cost_details': {'upstream_inference_completions_cost': 4.25e-05, 'upstream_inference_prompt_cost': 3.69e-05, 'upstream_inference_cost': 7.94e-05}}, id='lc_run--019ffbdc-a457-78f3-bd17-01fe3139246a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 123, 'output_tokens': 17, 'total_tokens': 140, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'reasoning': 0}})]

# %%
print(response["messages"][1].tool_calls)
# Out:
# [{'name': 'square_root', 'args': {'x': 467}, 'id': 'call_232205', 'type': 'tool_call'}]
